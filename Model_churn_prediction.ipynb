# %% [markdown]
# # MODEL FOR CHURN PREDICTION

# %%
import pandas as pd
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from imblearn.combine import SMOTEENN

# %% [markdown]
# # Read CSV file

# %%
df=pd.read_csv("tel_churn.csv")
df.head()
# Out:
#    Unnamed: 0  SeniorCitizen  Charges_Month  TotalCharges  Churn  \
# 0           0              0          64.85       1336.80      0
# 1           1              0          97.20       5129.45      0
# 2           2              0          23.45         23.45      1
# 3           3              0          70.20        237.95      1
# 4           5              0          69.55        521.35      0
#
#    gender_Female  gender_Male  Partner_No  Partner_Yes  Dependents_No  ...  \
# 0           True        False        True        False          False  ...
# 1           True        False        True        False           True  ...
# 2          False         True       False         True           True  ...
# 3          False         True        True        False           True  ...
# 4          False         True        True        False           True  ...
#
#    Method_Payment_Bank transfer (automatic)  \
# 0                                     False
# 1                                      True
# 2                                     False
# 3                                     False
# 4                                     False
#
#    Method_Payment_Credit card (automatic)  Method_Payment_Electronic check  \
# 0                                   False                            False
# 1                                   False                            False
# 2                                   False                             True
# 3                                   False                             True
# 4                                   False                             True
#
#    Method_Payment_Mailed check  tenure_group_1 - 12  tenure_group_13 - 24  \
# 0                         True                False                  True
# 1                        False                False                 False
# 2                        False                 True                 False
# 3                        False                 True                 False
# 4                        False                 True                 False
#
#    tenure_group_25 - 36  tenure_group_37 - 48  tenure_group_49 - 60  \
# 0                 False                 False                 False
# 1                 False                 False                  True
# 2                 False                 False                 False
# 3                 False                 False                 False
# 4                 False                 False                 False
#
#    tenure_group_61 - 72
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
#
# [5 rows x 52 columns]

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
x=df.drop('Churn',axis=1)
x
# Out:
#       SeniorCitizen  Charges_Month  TotalCharges  gender_Female  gender_Male  \
# 0                 0          64.85       1336.80           True        False
# 1                 0          97.20       5129.45           True        False
# 2                 0          23.45         23.45          False         True
# 3                 0          70.20        237.95          False         True
# 4                 0          69.55        521.35          False         True
# ...             ...            ...           ...            ...          ...
# 5619              0          95.00         95.00          False         True
# 5620              0          91.10       2198.30           True        False
# 5621              0          21.15        306.05          False         True
# 5622              1          99.45       1200.15          False         True
# 5623              0          19.80        457.30          False         True
#
#       Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  PhoneService_No  \
# 0           True        False          False            True            False
# 1           True        False           True           False            False
# 2          False         True           True           False             True
# 3           True        False           True           False            False
# 4           True        False           True           False            False
# ...          ...          ...            ...             ...              ...
# 5619       False         True           True           False            False
# 5620       False         True          False            True            False
# 5621       False         True          False            True            False
# 5622        True        False           True           False            False
# 5623        True        False           True           False            False
#
#       ...  Method_Payment_Bank transfer (automatic)  \
# 0     ...                                     False
# 1     ...                                      True
# 2     ...                                     False
# 3     ...                                     False
# 4     ...                                     False
# ...   ...                                       ...
# 5619  ...                                     False
# 5620  ...                                     False
# 5621  ...                                     False
# 5622  ...                                     False
# 5623  ...                                     False
#
#       Method_Payment_Credit card (automatic)  Method_Payment_Electronic check  \
# 0                                      False                            False
# 1                                      False                            False
# 2                                      False                             True
# 3                                      False                             True
# 4                                      False                             True
# ...                                      ...                              ...
# 5619                                   False                             True
# 5620                                    True                            False
# 5621                                   False                             True
# 5622                                   False                             True
# 5623                                    True                            False
#
#       Method_Payment_Mailed check  tenure_group_1 - 12  tenure_group_13 - 24  \
# 0                            True                False                  True
# 1                           False                False                 False
# 2                           False                 True                 False
# 3                           False                 True                 False
# 4                           False                 True                 False
# ...                           ...                  ...                   ...
# 5619                        False                 True                 False
# 5620                        False                False                  True
# 5621                        False                 True                 False
# 5622                        False                 True                 False
# 5623                        False                False                 False
#
#       tenure_group_25 - 36  tenure_group_37 - 48  tenure_group_49 - 60  \
# 0                    False                 False                 False
# 1                    False                 False                  True
# 2                    False                 False                 False
# 3                    False                 False                 False
# 4                    False                 False                 False
# ...                    ...                   ...                   ...
# 5619                 False                 False                 False
# 5620                 False                 False                 False
# 5621                 False                 False                 False
# 5622                 False                 False                 False
# 5623                  True                 False                 False
#
#       tenure_group_61 - 72
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# ...                    ...
# 5619                 False
# 5620                 False
# 5621                 False
# 5622                 False
# 5623                 False
#
# [5624 rows x 50 columns]

# %%
y=df['Churn']
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 5619    1
# 5620    0
# 5621    0
# 5622    1
# 5623    0
# Name: Churn, Length: 5624, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model_dt=DecisionTreeClassifier(criterion = "gini",random_state = 100,max_depth=6, min_samples_leaf=8)

# %%
model_dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=6, min_samples_leaf=8, random_state=100)

# %%
DecisionTreeClassifier(max_depth=6, min_samples_leaf=8, random_state=100)
# Out:
# DecisionTreeClassifier(max_depth=6, min_samples_leaf=8, random_state=100)

# %%
y_pred=model_dt.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 1], dtype=int64)

# %%
model_dt.score(x_test,y_test)
# Out:
# 0.7822222222222223

# %%
print(classification_report(y_test, y_pred, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.91      0.86       798
#            1       0.68      0.48      0.56       327
#
#     accuracy                           0.78      1125
#    macro avg       0.74      0.69      0.71      1125
# weighted avg       0.77      0.78      0.77      1125

# %%
import os
import multiprocessing

# Determine the number of logical cores
logical_cores = multiprocessing.cpu_count()
os.environ['LOKY_MAX_CPU_COUNT'] = str(logical_cores)

# %%
sm = SMOTEENN()
X_resampled1, y_resampled1 = sm.fit_resample(x,y)

# %%
xr_train1,xr_test1,yr_train1,yr_test1=train_test_split(X_resampled1, y_resampled1,test_size=0.2)

# %%
model_dt_smote=DecisionTreeClassifier(criterion = "gini",random_state = 100,max_depth=6, min_samples_leaf=8)

# %%
model_dt_smote.fit(xr_train1,yr_train1)
yr_predict = model_dt_smote.predict(xr_test1)
model_score_r = model_dt_smote.score(xr_test1, yr_test1)
print(model_score_r)
print(metrics.classification_report(yr_test1, yr_predict))
# Out:
# 0.9284140969162996
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92       418
#            1       0.93      0.94      0.93       490
#
#     accuracy                           0.93       908
#    macro avg       0.93      0.93      0.93       908
# weighted avg       0.93      0.93      0.93       908

# %%
print(metrics.confusion_matrix(yr_test1, yr_predict))
# Out:
# [[381  37]
#  [ 28 462]]

# %% [markdown]
# # RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_rf=RandomForestClassifier(n_estimators=100, criterion='gini', random_state = 100,max_depth=6, min_samples_leaf=8)

# %%
model_rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=6, min_samples_leaf=8, random_state=100)

# %%
y_pred=model_rf.predict(x_test)

# %%
model_rf.score(x_test,y_test)
# Out:
# 0.7991111111111111

# %%
print(classification_report(y_test, y_pred, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.94      0.87       798
#            1       0.75      0.46      0.57       327
#
#     accuracy                           0.80      1125
#    macro avg       0.78      0.70      0.72      1125
# weighted avg       0.79      0.80      0.78      1125

# %%
sm = SMOTEENN()
X_resampled1, y_resampled1 = sm.fit_resample(x,y)

# %%
xr_train1,xr_test1,yr_train1,yr_test1=train_test_split(X_resampled1, y_resampled1,test_size=0.2)

# %%
model_rf_smote=RandomForestClassifier(n_estimators=100, criterion='gini', random_state = 100,max_depth=6, min_samples_leaf=8)

# %%
model_rf_smote.fit(xr_train1,yr_train1)
# Out:
# RandomForestClassifier(max_depth=6, min_samples_leaf=8, random_state=100)

# %%
yr_predict1 = model_rf_smote.predict(xr_test1)

# %%
model_score_r1 = model_rf_smote.score(xr_test1, yr_test1)

# %%
print(model_score_r1)
print(metrics.classification_report(yr_test1, yr_predict1))
# Out:
# 0.947136563876652
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94       398
#            1       0.95      0.96      0.95       510
#
#     accuracy                           0.95       908
#    macro avg       0.95      0.95      0.95       908
# weighted avg       0.95      0.95      0.95       908

# %%
print(metrics.confusion_matrix(yr_test1, yr_predict1))
# Out:
# [[370  28]
#  [ 20 490]]

# %% [markdown]
# # With RF Classifier, also we are able to get quite good results, better than Decision Tree.
